# %%
nama_mhs1="Abdillah Julius"
nama_mhs2="Al Raffi Akbar"
print(nama_mhs1,"dan",nama_mhs2,"adalah mahasiswa TRKJ\nFakultas Teknologi Industri, Universitas Bung Hatta")
# Out:
# Abdillah Julius dan Al Raffi Akbar adalah mahasiswa TRKJ
# Fakultas Teknologi Industri, Universitas Bung Hatta

# %%
# Spelling correction menggunakan Python
# !pip install pyspellchecker
from spellchecker import SpellChecker
spell = SpellChecker()
# Input teks dari user.
text = input ("Input text: ")
# Cek spelling dari input teks.
corrected_text = spell.correction(text)
# Print the corrected text.
print(corrected_text)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 3.0 MB/s eta 0:00:00
# ...
# Input text: Abdil
# bail

# %%
#contoh if dua kondisi
angka = int(input('Masukkan angka: '))
if (angka % 2 == 0):
   print('Angka genap terdeteksi')
   print('%d adalah angka genap' % (angka))
else:
   print('Angka ganjil terdeteksi')
   print('%d adalah angka ganjil' % (angka))
# Out:
# Masukkan angka: 10
# Angka genap terdeteksi
# 10 adalah angka genap

# %%
#contoh penggunaan for untuk list
INDbidang = ['Internet of Things', 'Machine Learning', 'Jaringan Komputer', 'Pemrograman Web']
for i in INDbidang:
   print(i)
# Out:
# Internet of Things
# Machine Learning
# Jaringan Komputer
# Pemrograman Web

# %%
#contoh penggunaan while
i = 0
while (i <= 6):
   print(i)
   i += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#contoh penggunaan while dan break
i = 0
while (i <= 6):
   print(i)
   i += 0
   break #break setelah proses increment

print('Pesan ini di luar perulangan')
# Out:
# 0
# Pesan ini di luar perulangan
